# %%
import mediapipe as mp
import cv2

# %%
mp_detection=mp.solutions.face_detection
mp_drawing=mp.solutions.drawing_utils

# %%
face_detect=mp_detection.FaceDetection()

# %%
video=cv2.VideoCapture(0)
while True:
    suc,img=video.read()
    img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result=face_detect.process(img1)
    print(result.detections)
    if result.detections:
        for x in result.detections:
            # mp_drawing.draw_landmarks(img,x)    # to form the land mark
             mp_drawing.draw_detection(img,x)

    cv2.imshow("Face",img)
    if cv2.waitKey(1) & 0XFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# [label_id: 0
# score: 0.905433714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.51543045
#     ymin: 0.568613946
#     width: 0.334983945
#     height: 0.446619809
#   }
#   relative_keypoints {
#     x: 0.64079845
#     y: 0.693829238
#   }
#   relative_keypoints {
#     x: 0.782880425
#     y: 0.674550831
#   }
#   relative_keypoints {
#     x: 0.749045312
#     y: 0.784362376
#   }
#   relative_keypoints {
#     x: 0.746365368
#     y: 0.883408248
#   }
#   relative_keypoints {
#     x: 0.522022784
#     y: 0.760791063
#   }
#   relative_keypoints {
#     x: 0.821551859
#     y: 0.710967481
#   }
# }
# ]
# [label_id: 0
# score: 0.869596362
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.518585682
#     ymin: 0.574303389
#     width: 0.33361
#     height: 0.444785953
#   }
#   relative_keypoints {
#     x: 0.634374
#     y: 0.705854654
#   }
#   relative_keypoints {
#     x: 0.776932
# ...
